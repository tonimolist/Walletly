# %%
import sys 
sys.path.append("../src")

# %%
from domain import (
    Base, 
    engine,
)

engine.url
# Out:
# sqlite:///:memory:

# %%
Base.metadata.create_all(engine)

print(Base.metadata.tables.keys())
# Out:
# dict_keys(['transaction_tag', 'users', 'financial_profile', 'budget', 'category', 'budget_category', 'payment_method', 'transaction_type', 'transactions', 'tag'])
